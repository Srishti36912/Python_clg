# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\shris\OneDrive\Desktop\Python_clg\B.Tech (DS & AI) Marks - 51,52.csv")

# %%
df
# Out:
#     Sr No.            Student Name  Enrollment Number  marks
# 0        1           Utkarsh Gupta       2.022100e+14   27.0
# 1        2          Utkarsh Mishra       2.022100e+14   20.0
# 2        3             Rishabh Pal       2.022100e+14    NaN
# 3        4         Sankalp Jaiswal       2.022100e+14   27.0
# 4        5               Aman Ojha       2.022100e+14   22.0
# 5        6      Prateek Srivastava       2.022100e+14   21.0
# 6        7             Gopal Gupta       2.022100e+14   16.0
# 7        8       Sanjeev Kumar Pal       2.022100e+14    NaN
# 8        9          Vineet Shekhar       2.022100e+14   28.0
# 9       10           Aviral Shukla       2.022100e+14    NaN
# 10      11             Vivek Kumar       2.022100e+14   22.0
# 11      12              Haider Ali       2.022100e+14   24.0
# 12      13            Anshul Patel       2.022100e+14   21.0
# 13      14              Nitin Sahu       2.022100e+14   21.0
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Sr No.            Student Name  Enrollment Number  marks
# 0        1           Utkarsh Gupta       2.022100e+14   27.0
# 1        2          Utkarsh Mishra       2.022100e+14   20.0
# 3        4         Sankalp Jaiswal       2.022100e+14   27.0
# 4        5               Aman Ojha       2.022100e+14   22.0
# 5        6      Prateek Srivastava       2.022100e+14   21.0
# 6        7             Gopal Gupta       2.022100e+14   16.0
# 8        9          Vineet Shekhar       2.022100e+14   28.0
# 10      11             Vivek Kumar       2.022100e+14   22.0
# 11      12              Haider Ali       2.022100e+14   24.0
# 12      13            Anshul Patel       2.022100e+14   21.0
# 13      14              Nitin Sahu       2.022100e+14   21.0
# 14      15           Prakher Verma       2.022100e+14   22.0
# 15      16          Adarsh Jaiswal       2.022100e+14   21.0
# 16      17     Kushagra Chaturvedi       2.022100e+14   25.0
# ...

# %%
df.drop(["Sr No.","Enrollment Number"], inplace=True, axis=1)

# %%
df
# Out:
#               Student Name  marks
# 0            Utkarsh Gupta   27.0
# 1           Utkarsh Mishra   20.0
# 3          Sankalp Jaiswal   27.0
# 4                Aman Ojha   22.0
# 5       Prateek Srivastava   21.0
# 6              Gopal Gupta   16.0
# 8           Vineet Shekhar   28.0
# 10             Vivek Kumar   22.0
# 11              Haider Ali   24.0
# 12            Anshul Patel   21.0
# 13              Nitin Sahu   21.0
# 14           Prakher Verma   22.0
# 15          Adarsh Jaiswal   21.0
# 16     Kushagra Chaturvedi   25.0
# 17       Srijan Srivastava   20.0
# 18          Suryansh Vaish   20.0
# 19         Shivendra Gupta   20.0
# 20     Shashwat Srivastava   15.0
# 21           Anishka Singh   27.0
# 22        Srishti Tripathi   28.0
# 23            Imran Ansari   20.0
# 24              Omi Mishra   28.0
# 25                Anchal .   28.0
# 26         Sudhanshu Kumar   19.0
# 27     Piyanshi Srivastava   16.0
# 28     Shubham Kumar Verma   16.0
# ...

# %%
a = df['Student Name'].values

# %%
a
# Out:
# array(['Utkarsh Gupta', 'Utkarsh Mishra', 'Sankalp Jaiswal', 'Aman Ojha',
#        'Prateek Srivastava', 'Gopal Gupta', 'Vineet Shekhar',
#        'Vivek Kumar', 'Haider Ali', 'Anshul Patel', 'Nitin Sahu',
#        'Prakher Verma', 'Adarsh Jaiswal', 'Kushagra Chaturvedi',
#        'Srijan Srivastava', 'Suryansh Vaish', 'Shivendra Gupta',
#        'Shashwat Srivastava', 'Anishka Singh', 'Srishti Tripathi',
#        'Imran Ansari', 'Omi Mishra', 'Anchal .', 'Sudhanshu Kumar',
#        'Piyanshi Srivastava', 'Shubham Kumar Verma', 'Prajjwal Pandey',
#        'Neeraj Gautam', 'Mohd Shadan', 'Ujjwal Srivastava',
#        'Kritagya Bhagat', 'Harivansh Singh', 'Varunendra Kumar Verma',
#        'Anushka Agarwal', 'Anshika Pandey', 'Naman Mishra',
#        'Pratigya Tripathi', 'Kushagra Jain', 'Garima Rao', 'Ayush Singh',
#        'Arpit Swarnkar', 'Ranvijay Singh', 'Prachi Rao',
#        'Priyanshu Sahai', 'Aryan Srivastava', 'Kaustubh Singh',
# ...

# %%
b = df["marks"].values

# %%
plt.figure(figsize=(19,8))
plt.bar(a,b,color="k")
plt.grid(axis="y", color='r')
plt.xticks(rotation=90)

plt.xlabel("Student Name", size=30, color='r')
plt.ylabel("Student Marks", size=30)
plt.tight_layout()
plt.show()
