# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\shris\OneDrive\Desktop\Python_clg\matches.csv")

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head() # used to display first few rows, by default it shows the top 5 rows
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.tail() # similar to head() but it displays the last few rows
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  22-05-2016     Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016        Gujarat Lions
# 633  634    2016      Delhi  25-05-2016  Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016        Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.shape
# Out:
# (636, 18)

# %%
df.info() # provides a concise summary of dataframe which includes details about its structure and content
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.describe() # provides a summary of statistics for numerical columns
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.size # gives total number of elements
# Out:
# 11448

# %%
df.values # returns data as numpy array
# Out:
# array([[1, 2017, 'Hyderabad', ..., 'AY Dandekar', 'NJ Llong', nan],
#        [2, 2017, 'Pune', ..., 'A Nand Kishore', 'S Ravi', nan],
#        [3, 2017, 'Rajkot', ..., 'Nitin Menon', 'CK Nandan', nan],
#        ...,
#        [634, 2016, 'Delhi', ..., 'M Erasmus', 'C Shamshuddin', nan],
#        [635, 2016, 'Delhi', ..., 'M Erasmus', 'CK Nandan', nan],
#        [636, 2016, 'Bangalore', ..., 'HDPK Dharmasena', 'BNJ Oxenford',
#         nan]], dtype=object)

# %%
df.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
df.index # returns the index (row labels) of the dataframe
# Out:
# RangeIndex(start=0, stop=636, step=1)

# %%
df.columns  # returns the column labels of the dataframe
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.drop(["umpire3"], axis=1) # drops a column
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df # dataframe remains unchanged
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
import pandas as pd
df1 = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df1.drop('B', axis=1, inplace=True) # dropping B and modify df in place
df1
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %% [markdown]
# The inplace parameter in a method is used to change the original dataframe directly. When you set inplace= True, the method modifies the dataframe you're working with
#
#
# If you set inplace= False (or omits it, as it defaults to False), original datafrme remains unchanged.

# %%
df1.drop(1, axis=0)
# Out:
#    A
# 0  1
# 2  3

# %% [markdown]
# # Fetching rows and columns using iloc and loc

# %% [markdown]
# iloc and loc are two powerful ways to select and filter data from a Pandas DataFrame.
#
# They work differently based on the type of index you want to use: integer-based or label-based.

# %% [markdown]
# ### iloc (Integer Location):
#
# Use Case- Select rows and columns by their position (integer index).
#
# Works with - Integer-based positions (starting from 0).
#
# Syntax - df.iloc[row_index, column_index]

# %% [markdown]
# ### loc (Label Location):
#
# Use Case- Select rows and columns by their label (row/column name).
#
# Works with - Labels (row/column names).
#
# Syntax - df.loc[row_label, column_label]

# %%
df['winner']        # Single square brackets[]: Used to select a single column, which returns a Series.
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
df['winner'].shape
# Out:
# (636,)

# %%
type(df['winner'])
# Out:
# pandas.core.series.Series

# %%
df[['team1','team2','winner']] # Double square brackets[[]]: Used to select a multiple columns or to ensure the result is a DataFrame,
                               #even when selecting one column
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df[['team1','team2','winner']].shape
# Out:
# (636, 3)

# %%
type(df[['team1','team2','winner']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              05-04-2017
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
df.iloc[1:6] # slice rows from 1 to 5
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  09-04-2017                Gujarat Lions
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.iloc[0:11:2] # select rows from index 0 to 10 with a step of 2
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 2    3    2017     Rajkot  07-04-2017                Gujarat Lions
# 4    5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 6    7    2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 8    9    2017       Pune  11-04-2017             Delhi Daredevils
# 10  11    2017    Kolkata  13-04-2017              Kings XI Punjab
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 6                Mumbai Indians               Mumbai Indians         field
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
df.iloc[[3,55,611,129]] # fancy indexing allows you to select specific rows by providing a list of row indices, rather than a range or slice.
# Out:
#       id  season        city        date                   team1  \
# 3      4    2017      Indore  08-04-2017  Rising Pune Supergiant
# 55    56    2017      Mumbai  16-05-2017  Rising Pune Supergiant
# 611  612    2016  Chandigarh  07-05-2016         Kings XI Punjab
# 129  130    2009   Cape Town  26-04-2009         Kings XI Punjab
#
#                 team2       toss_winner toss_decision  result  dl_applied  \
# 3     Kings XI Punjab   Kings XI Punjab         field  normal           0
# 55     Mumbai Indians    Mumbai Indians         field  normal           0
# 611  Delhi Daredevils  Delhi Daredevils         field  normal           0
# 129  Rajasthan Royals   Kings XI Punjab           bat  normal           0
#
#                      winner  win_by_runs  win_by_wickets    player_of_match  \
# 3           Kings XI Punjab            0               6         GJ Maxwell
# 55   Rising Pune Supergiant           20               0  Washington Sundar
# ...

# %%
df.iloc[:,[4,6,10]] # select all rows, and columns with indices 4, 6, and 10
# Out:
#                            team1                  toss_winner  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df.loc[3] # select the row with label
# Out:
# id                                      4
# season                               2017
# city                               Indore
# date                           08-04-2017
# team1              Rising Pune Supergiant
# team2                     Kings XI Punjab
# toss_winner               Kings XI Punjab
# toss_decision                       field
# result                             normal
# dl_applied                              0
# winner                    Kings XI Punjab
# win_by_runs                             0
# win_by_wickets                          6
# player_of_match                GJ Maxwell
# venue              Holkar Cricket Stadium
# umpire1                      AK Chaudhary
# umpire2                     C Shamshuddin
# umpire3                               NaN
# Name: 3, dtype: object

# %%
df.loc[::2] # selects every second row, starting from the first row.
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 2      3    2017         Rajkot  07-04-2017                Gujarat Lions
# 4      5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 6      7    2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 8      9    2017           Pune  11-04-2017             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 626  627    2016         Kanpur  19-05-2016        Kolkata Knight Riders
# 628  629    2016  Visakhapatnam  21-05-2016              Kings XI Punjab
# 630  631    2016        Kolkata  22-05-2016        Kolkata Knight Riders
# 632  633    2016      Bangalore  24-05-2016                Gujarat Lions
# 634  635    2016          Delhi  27-05-2016                Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.loc[:,["team1","team2"]] # you cannot use integer based indexing for columns instead it requires column names (labels) to select columns.
# Out:
#                            team1                        team2
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
# [636 rows x 2 columns]

# %% [markdown]
# # Filtering DatFrame on a condition

# %%
df["city"] == "Hyderabad" #This expression returns a Series of boolean values 
                          #indicationg whether each row in the "city" column matches "Hyderabad"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
fil = df["city"] == "Hyderabad"

# %%
df[fil] # or we can direcly use df[df["city"] == "Hyderabad"]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  09-04-2017                Gujarat Lions
# 18    19    2017  Hyderabad  17-04-2017          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  19-04-2017          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  30-04-2017          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  06-05-2017       Rising Pune Supergiant
# 46    47    2017  Hyderabad  08-05-2017               Mumbai Indians
# 58    59    2017  Hyderabad  21-05-2017               Mumbai Indians
# 65    66    2008  Hyderabad  22-04-2008              Deccan Chargers
# 67    68    2008  Hyderabad  24-04-2008              Deccan Chargers
# 76    77    2008  Hyderabad  01-05-2008              Deccan Chargers
# 79    80    2008  Hyderabad  25-05-2008              Deccan Chargers
# 91    92    2008  Hyderabad  11-05-2008        Kolkata Knight Riders
# ...

# %%
df[fil].shape # shape return output as a form of tuple....You can index this tuple
# Out:
# (49, 18)

# %%
df[fil].shape[0] # this 49 indicate total matches were played in Hyderabad
# Out:
# 49

# %%
# This function is designed to count the number of rows in the DataFrame where the "city" columns matches the specified city.
def get_city_match_count(city):
    filter_data = df["city"] == city
    return df[filter_data].shape[0]

# %%
get_city_match_count("Pune")
# Out:
# 32

# %%
get_city_match_count("Rajkot")
# Out:
# 10

# %%
df["date"]
# Out:
# 0      05-04-2017
# 1      06-04-2017
# 2      07-04-2017
# 3      08-04-2017
# 4      08-04-2017
#           ...
# 631    22-05-2016
# 632    24-05-2016
# 633    25-05-2016
# 634    27-05-2016
# 635    29-05-2016
# Name: date, Length: 636, dtype: object

# %%
fil2 = df["season"] > 2015

# %%
fil2
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 631    True
# 632    True
# 633    True
# 634    True
# 635    True
# Name: season, Length: 636, dtype: bool

# %%
fil1 = df["city"] == "Hyderabad"

# %%
df[fil1 & fil2].head()
# Out:
#     id  season       city        date                team1  \
# 0    1    2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 5    6    2017  Hyderabad  09-04-2017        Gujarat Lions
# 18  19    2017  Hyderabad  17-04-2017  Sunrisers Hyderabad
# 20  21    2017  Hyderabad  19-04-2017  Sunrisers Hyderabad
# 35  36    2017  Hyderabad  30-04-2017  Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 18              Kings XI Punjab              Kings XI Punjab         field
# 20             Delhi Daredevils          Sunrisers Hyderabad           bat
# 35        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#     result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0   normal           0  Sunrisers Hyderabad           35               0
# ...

# %%
df[fil1 & fil2].shape[0] # total 15 matches were played in hyderabad after 2015
# Out:
# 15

# %%
def city_match_after15(city):
    filter_data = df["city"] == city
    filter_data2 = df["season"] > 2015
    after15 = df[filter_data & filter_data2].shape[0]
    return after15

# %%
city_match_after15("Rajkot")  # total 10 matches were played in Rajkot after 2015
# Out:
# 10

# %%
city_match_after15("Pune")  # total 11 matches were played in Pune after 2015
# Out:
# 11

# %%
city_match_after15("Indore")
# Out:
# 3

# %% [markdown]
# Creating reuable functions like city_match_after15 is a great practice in programming.
#
# It allows you to perform repetitive tasks with ease and ensures consistency in your data analysis.

# %%
df["winner"].value_counts() # returns the frequency of each unique value in descending order.
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
df["team1"].value_counts()
# Out:
# team1
# Mumbai Indians                 82
# Kings XI Punjab                77
# Chennai Super Kings            77
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Delhi Daredevils               63
# Rajasthan Royals               54
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %%
df["team2"].value_counts()
# Out:
# team2
# Delhi Daredevils               84
# Royal Challengers Bangalore    82
# Kolkata Knight Riders          80
# Mumbai Indians                 75
# Kings XI Punjab                71
# Rajasthan Royals               64
# Chennai Super Kings            54
# Deccan Chargers                32
# Sunrisers Hyderabad            30
# Pune Warriors                  26
# Gujarat Lions                  16
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %%
df["team1"].value_counts() + df["team2"].value_counts() # total match played by each team

# Adding these two Series objects combines the counts for matching index values but it doesn't sort the combined result.
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %%
total_match = df["team1"].value_counts() + df["team2"].value_counts()

# %%
total_match.sort_values()
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Rising Pune Supergiant          16
# Gujarat Lions                   30
# Pune Warriors                   46
# Deccan Chargers                 75
# Sunrisers Hyderabad             76
# Rajasthan Royals               118
# Chennai Super Kings            131
# Delhi Daredevils               147
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Royal Challengers Bangalore    152
# Mumbai Indians                 157
# Name: count, dtype: int64

# %%
total_match.sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
df.sort_values('toss_decision') # you can use sort_values function in dataframe
# Out:
#       id  season       city        date                  team1  \
# 635  636    2016  Bangalore  29-05-2016    Sunrisers Hyderabad
# 492  493    2014  Hyderabad  12-05-2014    Sunrisers Hyderabad
# 263  264    2011     Mumbai  27-04-2011          Pune Warriors
# 493  494    2014     Ranchi  13-05-2014       Rajasthan Royals
# 498  499    2014     Ranchi  18-05-2014    Chennai Super Kings
# ..   ...     ...        ...         ...                    ...
# 265  266    2011      Delhi  28-04-2011  Kolkata Knight Riders
# 264  265    2011      Kochi  27-04-2011        Deccan Chargers
# 262  263    2011      Delhi  26-04-2011       Delhi Daredevils
# 277  278    2011      Kochi  05-05-2011   Kochi Tuskers Kerala
# 317  318    2012      Delhi  10-04-2012    Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
# ...

# %%
df.sort_values(['toss_decision','toss_winner'])
# Out:
#       id  season            city        date                  team1  \
# 60    61    2008      Chandigarh  19-04-2008    Chennai Super Kings
# 73    74    2008       Bangalore  28-04-2008    Chennai Super Kings
# 78    79    2008         Chennai  02-05-2008    Chennai Super Kings
# 82    83    2008          Jaipur  04-05-2008    Chennai Super Kings
# 121  122    2009  Port Elizabeth  20-04-2009    Chennai Super Kings
# ..   ...     ...             ...         ...                    ...
# 590  591    2016          Rajkot  21-04-2016          Gujarat Lions
# 593  594    2016       Hyderabad  23-04-2016        Kings XI Punjab
# 609  610    2016       Hyderabad  06-05-2016          Gujarat Lions
# 630  631    2016         Kolkata  22-05-2016  Kolkata Knight Riders
# 634  635    2016           Delhi  27-05-2016          Gujarat Lions
#
#                            team2          toss_winner toss_decision  result  \
# ...

# %%
x = df.sort_values(['toss_decision','toss_winner'])

# %%
x[['toss_winner','toss_decision']]
# Out:
#              toss_winner toss_decision
# 60   Chennai Super Kings           bat
# 73   Chennai Super Kings           bat
# 78   Chennai Super Kings           bat
# 82   Chennai Super Kings           bat
# 121  Chennai Super Kings           bat
# ..                   ...           ...
# 590  Sunrisers Hyderabad         field
# 593  Sunrisers Hyderabad         field
# 609  Sunrisers Hyderabad         field
# 630  Sunrisers Hyderabad         field
# 634  Sunrisers Hyderabad         field
#
# [636 rows x 2 columns]

# %%
x[['toss_winner','toss_decision']].value_counts()
# Out:
# toss_winner                  toss_decision
# Royal Challengers Bangalore  field            50
# Kolkata Knight Riders        field            48
# Delhi Daredevils             field            46
# Mumbai Indians               field            45
# Chennai Super Kings          bat              44
# Kings XI Punjab              field            43
# Mumbai Indians               bat              40
# Rajasthan Royals             field            35
# Kolkata Knight Riders        bat              30
# Rajasthan Royals             bat              28
# Delhi Daredevils             bat              26
# Kings XI Punjab              bat              25
# Deccan Chargers              bat              24
# Chennai Super Kings          field            22
# Royal Challengers Bangalore  bat              20
# Deccan Chargers              field            19
# Sunrisers Hyderabad          bat              18
#                              field            17
# ...

# %%
x[['toss_winner']].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
df['player_of_match'].value_counts()
# Out:
# player_of_match
# CH Gayle             18
# YK Pathan            16
# DA Warner            15
# AB de Villiers       15
# RG Sharma            14
#                      ..
# SA Yadav              1
# Mustafizur Rahman     1
# CR Brathwaite         1
# A Zampa               1
# BCJ Cutting           1
# Name: count, Length: 201, dtype: int64

# %%
virat = df['player_of_match'] == "V Kohli"
virat.value_counts().values[1]               # virat kohli player of the match 11 time according to this dataset
# Out:
# np.int64(11)

# %% [markdown]
# # drop duplicate function

# %%
df.drop_duplicates("city")
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017            Pune  06-04-2017               Mumbai Indians
# 2      3    2017          Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017          Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017       Bangalore  08-04-2017  Royal Challengers Bangalore
# 6      7    2017          Mumbai  09-04-2017        Kolkata Knight Riders
# 10    11    2017         Kolkata  13-04-2017              Kings XI Punjab
# 14    15    2017           Delhi  15-04-2017             Delhi Daredevils
# 31    32    2017      Chandigarh  28-04-2017          Sunrisers Hyderabad
# 48    49    2017          Kanpur  10-05-2017                Gujarat Lions
# 64    65    2008          Jaipur  21-04-2008              Kings XI Punjab
# 66    67    2008         Chennai  23-04-2008          Chennai Super Kings
# ...

# %%
df.drop_duplicates("city").shape
# Out:
# (31, 18)

# %%
df.drop_duplicates(["city","season"])
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017           Pune  06-04-2017               Mumbai Indians
# 2      3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 583  584    2016      Hyderabad  16-04-2016          Sunrisers Hyderabad
# 591  592    2016           Pune  22-04-2016  Royal Challengers Bangalore
# 612  613    2016  Visakhapatnam  08-05-2016          Sunrisers Hyderabad
# 626  627    2016         Kanpur  19-05-2016        Kolkata Knight Riders
# 627  628    2016         Raipur  20-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.drop_duplicates(["city","season"]).shape
# Out:
# (107, 18)

# %%
df.drop_duplicates("season")
# Out:
#       id  season       city        date                  team1  \
# 0      1    2017  Hyderabad  05-04-2017    Sunrisers Hyderabad
# 59    60    2008  Bangalore  18-04-2008  Kolkata Knight Riders
# 117  118    2009  Cape Town  18-04-2009         Mumbai Indians
# 174  175    2010     Mumbai  12-03-2010  Kolkata Knight Riders
# 234  235    2011    Chennai  08-04-2011    Chennai Super Kings
# 307  308    2012    Chennai  04-04-2012    Chennai Super Kings
# 381  382    2013    Kolkata  03-04-2013       Delhi Daredevils
# 457  458    2014  Abu Dhabi  16-04-2014  Kolkata Knight Riders
# 517  518    2015    Kolkata  08-04-2015         Mumbai Indians
# 576  577    2016     Mumbai  09-04-2016         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.drop_duplicates("season").shape
# Out:
# (10, 18)

# %%
df.drop_duplicates("season",keep = "last")
# Out:
#       id  season          city        date                team1  \
# 58    59    2017     Hyderabad  21-05-2017       Mumbai Indians
# 116  117    2008        Mumbai  01-06-2008  Chennai Super Kings
# 173  174    2009  Johannesburg  24-05-2009      Deccan Chargers
# 233  234    2010        Mumbai  25-04-2010  Chennai Super Kings
# 306  307    2011       Chennai  28-05-2011  Chennai Super Kings
# 380  381    2012       Chennai  27-05-2012  Chennai Super Kings
# 456  457    2013       Kolkata  26-05-2013       Mumbai Indians
# 516  517    2014     Bangalore  01-06-2014      Kings XI Punjab
# 575  576    2015       Kolkata  24-05-2015       Mumbai Indians
# 635  636    2016     Bangalore  29-05-2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 58        Rising Pune Supergiant               Mumbai Indians           bat
# 116             Rajasthan Royals             Rajasthan Royals         field
# ...

# %%
season_win = df.drop_duplicates("season",keep = "last")
season_win[["season","winner"]]
# Out:
#      season                 winner
# 58     2017         Mumbai Indians
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad

# %%
season_win[["season","winner"]].sort_values("season")
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians
